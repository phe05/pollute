# %% [markdown]
# <a href="https://colab.research.google.com/github/phe05/pollute/blob/main/%EC%98%A4%EC%97%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = 'http://apis.data.go.kr/B552584/OzYlwsndOccrrncInforInqireSvc/getOzAdvsryOccrrncInfo'
params ={'serviceKey' : 'm06NJk3GZEY%2BRmrYE6iGsIzir8rhjgMjA6rop6RqkHRTMsk3UngO8D%2BIV8p6DRt%2BdFtipRUB%2Bm81sXVoSQAiOQ%3D%3D', 'returnType' : 'xml', 'numOfRows' : '100', 'pageNo' : '1', 'year' : '2023' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\r\n<response>\n  <header>\n    <resultCode>00</resultCode>\n    <resultMsg>NORMAL_CODE</resultMsg>\n  </header>\n  <body>\n    <items>\n      <item>\n        <clearVal>.113</clearVal>\n        <sn>348</sn>\n        <maxVal>.126</maxVal>\n        <districtName>\xea\xb2\xbd\xeb\x82\xa8</districtName>\n        <dataDate>2023-10-18</dataDate>\n        <issueVal>.126</issueVal>\n        <issueLvl>1</issueLvl>\n        <issueTime>16</issueTime>\n        <moveName>\xec\xa7\x84\xec\xa3\xbc\xec\x8b\x9c</moveName>\n        <clearTime>17</clearTime>\n      </item>\n      <item>\n        <clearVal>.1044</clearVal>\n        <sn>347</sn>\n        <maxVal>.1286</maxVal>\n        <districtName>\xec\xa0\x84\xeb\x82\xa8</districtName>\n        <dataDate>2023-10-04</dataDate>\n        <issueVal>.1286</issueVal>\n        <issueLvl>1</issueLvl>\n        <issueTime>13</issueTime>\n        <moveName>\xec\x97\xac\xec\x88\x98\xec\x8b\x9c</moveName>\n        <clearTime
# ...

# %%
soup = BeautifulSoup(response.text, features="xml")

# %%
soup.find_all('clearTime')
# Out:
# [<clearTime>17</clearTime>,
#  <clearTime>14</clearTime>,
#  <clearTime>16</clearTime>,
#  <clearTime>13</clearTime>,
#  <clearTime>16</clearTime>,
#  <clearTime>17</clearTime>,
#  <clearTime>17</clearTime>,
#  <clearTime>17</clearTime>,
#  <clearTime>16</clearTime>,
#  <clearTime>18</clearTime>,
#  <clearTime>15</clearTime>,
#  <clearTime>18</clearTime>,
#  <clearTime>18</clearTime>,
#  <clearTime>19</clearTime>,
#  <clearTime>19</clearTime>,
#  <clearTime>19</clearTime>,
#  <clearTime>15</clearTime>,
#  <clearTime>15</clearTime>,
#  <clearTime>17</clearTime>,
#  <clearTime>19</clearTime>,
#  <clearTime>17</clearTime>,
#  <clearTime>18</clearTime>,
#  <clearTime>18</clearTime>,
#  <clearTime>18</clearTime>,
#  <clearTime>19</clearTime>,
#  <clearTime>17</clearTime>,
#  <clearTime>16</clearTime>,
#  <clearTime>14</clearTime>,
#  <clearTime>13</clearTime>,
#  <clearTime>19</clearTime>,
#  <clearTime>16</clearTime>,
#  <clearTime>16</clearTime>,
#  <clearTime>18</clearTime>,
# ...
